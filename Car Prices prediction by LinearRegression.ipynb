# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
# Ignore warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
df=pd.read_csv("/content/train.csv")

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# ...

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %% [markdown]
# **Task-01**

# %%
df['Fuel type']
# Out:
# 0        Hybrid
# 1        Petrol
# 2        Petrol
# 3        Hybrid
# 4        Petrol
#           ...
# 19232       CNG
# 19233    Petrol
# 19234    Diesel
# 19235    Diesel
# 19236    Hybrid
# Name: Fuel type, Length: 19237, dtype: object

# %%
filtered_df = df[~((df['Fuel type'].str.lower() == 'diesel') & (df['Prod. year'] < 2005))]
print(f"Number of rows after filtering: {len(filtered_df)}")
# Out:
# Number of rows after filtering: 18789

# %%
df.head(5)
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# ...

# %%
df.tail(5)
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year Category  \
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999    Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011    Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010     Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007     Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012    Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 19232              Yes       CNG     2.0 Turbo  300000 km          4
# 19233              Yes    Petrol           2.4  161600 km          4
# 19234              Yes    Diesel             2  116365 km          4
# 19235              Yes    Diesel             2   51258 km          4
# 19236              Yes    Hybrid           2.4  186923 km          4
#
#       Gear box type Drive wheels  Doors       Wheel   Color  Airbags
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/train.csv")
# Check if 'Levy' column exists
if 'Levy' in df.columns:
    # Convert 'Levy' column to numeric, handling errors by coercing to NaN
    df['Levy'] = pd.to_numeric(df['Levy'], errors='coerce')
    total_levy = df['Levy'].sum()

    total_records = len(df)

    # Calculate the average using the formula
    average_levy = total_levy / total_records

    # Display the result
    print(f"The average value of the 'Levy' column is: {average_levy}")
else:
    print("Column 'Levy' not found in DataFrame.")
# Out:
# The average value of the 'Levy' column is: 632.5286687113376

# %% [markdown]
# **Task-02**

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("/content/train.csv")
# Include 'Price' in the columns you select
df = df[['Category', 'Engine volume', 'Mileage', 'Cylinders', 'Price']]
y = df['Price']

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Check if 'Engine volume' is already numeric
if df['Engine volume'].dtype == object:
    df['Engine volume'] = df['Engine volume'].str.split(' ').str[0].astype(float)
else:
    print("'Engine volume' is already numeric. Skipping string conversion.")

df['Mileage'] = df['Mileage'].str.split(' ').str[0].astype(float)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import preprocessing

# Load the dataset
df = pd.read_csv("/content/train.csv")

# Include 'Price' in the columns you select
df = df[['Category', 'Engine volume', 'Mileage', 'Cylinders', 'Price']]

# Convert 'Engine volume' to numeric, handling potential errors
df['Engine volume'] = pd.to_numeric(df['Engine volume'].str.split(' ').str[0], errors='coerce')

# Convert 'Mileage' to numeric, handling potential errors
df['Mileage'] = pd.to_numeric(df['Mileage'].str.split(' ').str[0], errors='coerce')

# Encode 'Category' using Label Encoding
label_encoder = preprocessing.LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Drop rows with missing values in any of the relevant columns
df.dropna(subset=['Category', 'Engine volume', 'Mileage','Cylinders', 'Price'], inplace=True)


X = df[['Category', 'Engine volume', 'Mileage','Cylinders']]
y = df['Price']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=24)

# Create and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
r_squared = model.score(X_test, y_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"Linear regression R-squared value (Test Set): {r_squared:.3f}")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
# Out:
# Linear regression R-squared value (Test Set): -0.001
# Mean Absolute Error (MAE): 12361.805
# Mean Squared Error (MSE): 334848954.142

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import preprocessing

# Load the dataset
df = pd.read_csv("/content/test.csv")

# Include 'Price' in the columns you select
df = df[['Category', 'Engine volume', 'Mileage', 'Cylinders', 'Price']]

# Convert 'Engine volume' to numeric, handling potential errors
df['Engine volume'] = pd.to_numeric(df['Engine volume'].str.split(' ').str[0], errors='coerce')

# Convert 'Mileage' to numeric, handling potential errors
df['Mileage'] = pd.to_numeric(df['Mileage'].str.split(' ').str[0], errors='coerce')

# Encode 'Category' using Label Encoding
label_encoder = preprocessing.LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Drop rows with missing values in any of the relevant columns
df.dropna(subset=['Category', 'Engine volume', 'Mileage','Cylinders', 'Price'], inplace=True)


X = df[['Category', 'Engine volume', 'Mileage','Cylinders']]
y = df['Price']


# Create and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
r_squared = model.score(X_test, y_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"Linear regression R-squared value (Test Set): {r_squared:.3f}")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
# Out:
# Linear regression R-squared value (Test Set): -0.001
# Mean Absolute Error (MAE): 12361.805
# Mean Squared Error (MSE): 334848954.142

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

features = ['Category', 'Engine volume', 'Mileage', 'Cylinders', 'Price']
target = 'Price'
X = df[features].values
y = df[target].values



# Initialize parameters
theta = np.zeros(X_train_scaled.shape[1])

# Hyperparameters
alpha = 0.01  # Learning rate
iterations = 1000  # Number of iterations

# Cost function
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    errors = predictions - y
    cost = (1 / (2 * m)) * np.dot(errors.T, errors)
    return cost

# Gradient descent
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        gradient = (1 / m) * X.T.dot(errors)
        theta -= alpha * gradient
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# Train the model
theta, cost_history = gradient_descent(X_train_scaled, y_train, theta, alpha, iterations)

# Output the optimal weights and bias
bias = theta[0]
weights = theta[1:]
print("Optimal bias (intercept):", bias)
print("Optimal weights:", weights)

# Plotting the training cost vs iterations
plt.plot(range(iterations), cost_history, 'b-')
plt.xlabel('Iterations')
plt.ylabel('Cost (MSE)')
plt.title('Training Cost vs Iterations')
plt.show()

# Preprocess the test set
X_test_scaled = (X_test - X_mean) / X_std
m_test = X_test_scaled.shape[0]
X_test_scaled = np.hstack((np.ones((m_test, 1)), X_test_scaled))

# Make predictions on the test set
y_pred = X_test_scaled.dot(theta)

# Evaluate the model on the test set
test_cost = compute_cost(X_test_scaled, y_test, theta)
print("Test set cost (MSE):", test_cost)
# Out:
# Optimal bias (intercept): 18749.61586586476
# Optimal weights: [-3958.02604954  1682.27110303  -312.58165854   -60.53279894]
# Test set cost (MSE): 167485908.72197652
